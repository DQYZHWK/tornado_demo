# %%
联众病例504462,既往史,"高血压病史10余年，详见现病史。有“冠心病”、“慢性胃炎”病史10年余，未服药，否认“糖尿病”病史，否认“肾炎”等其他重大内科疾病史，否认“肝炎”、“结核”等传染病史，否认其他食物药物过敏史。否认手术及重大外伤病史，否认输血史，预防接种史不详。
"
联众病例500863,既往史,"既往体健。患者有尿频、排尿滴沥，在外院诊为“前列腺增生”，一直服用“保列治”治疗。无“高血压病、糖尿病、脑梗塞、胃炎”病史，50年前体检发现“陈旧性肺结核”。体检发现“右肺多发结节”。否认“肝炎、血吸虫、伤寒”传染病史，否认“输血”史，无“外伤、中毒”史；否认药物、食物过敏史。预防接种史具体不详。
"
联众病例507749,既往史,"既往体尚健，否认肝炎、肺结核等传染病史，有“高血压、冠心病、前列腺增生、胆囊结石”等病史（见现病史），否认糖尿病、慢性肾炎等重大疾病史，否认重大手术、外伤、输血、中毒史，否认明确药物、食物过敏史，预防接种史不详。
"
联众病例505149,家族史,"父死于“高血压、脑溢血”，母死于“气管炎”，有兄弟5人，均健在；否认2系3代家族性传染病、肿瘤、精神疾病、类似疾病及遗传疾病史。
"
联众病例510558,预防接种史,"预防接种史不详
"
联众病例499506,家族史,"父母已故，死因不详，有1弟健在，否认重大家族遗传病史、传染病史，否认家族性类似疾病史。
"
联众病例504108,月经史,"月经史：13,6-7,30,50绝经后未见异常阴道出血史。
"
联众病例503702,家族史,"父母已亡，死因不详。兄弟姐妹5人，兄弟姐妹均已故。家族中无类似疾病患者；无传染性、遗传性、家族性疾病。
"
联众病例506595,现病史,"患者于8年前（2010年3月）因“1型糖尿病糖尿病肾病慢性肾功能衰竭尿毒症”开始接受血透治疗，每周3次，以左前臂动静脉內瘘为血透通路，平时体重控制差，血压控制欠佳。4年前出现左前臂动静脉內瘘闭塞，予留置右颈内长期血透导管，继续血透治疗。2年前出现右颈内长期血透导管功能不良，予加用华法林抗凝治疗。11月前出现长期血透导管部分脱出，于10月前行左前臂动静脉内瘘成形术，现血管通路为左前臂动静脉内瘘。1天前患者无明显诱因下出现畏寒发热，体温最高37.8℃，阵发性咳嗽咳痰，痰白粘能咳出，咽痛，头痛，无鼻塞流涕，无胸闷气急，无恶心呕吐，无腹痛腹泻，自服散利痛退热处理，今晨仍有发热，现为进一步诊治入院。起病以来，患者精神软，胃纳睡眠欠佳，大便畅，无尿，体重增减情况不详。
"
联众病例499782,手术史,"无手术
"
联众病例507916,个人史,"出生于山东威海，59年来杭，检验所公务员，目前离休，否认疫区居留史；无烟酒嗜好，无其他特殊嗜好，无不洁性交史；无毒物接触史；已婚，家庭关系和睦。
"
联众病例502182,预防接种史,"预防接种史不详
# Out:
# 1

# %%
import zipp
urls = ['http://localhost:20001/api' for i in range(5)]
params = [{'ctx': "出生生长于杭州，未久居外地。否认疫水疫源地接触史，无烟酒等不良嗜好，无不洁性交史；无职业性粉尘、放射性物质、毒物接触史；家庭关系和睦。"}
          ,{'ctx': "父母已亡，死因不详。兄弟姐妹5人，兄弟姐妹均已故。家族中无类似疾病患者；无传染性、遗传性、家族性疾病。"}
          ,{'ctx':"既往体尚健，否认肝炎、肺结核等传染病史，有“高血压、冠心病、前列腺增生、胆囊结石”等病史（见现病史），否认糖尿病、慢性肾炎等重大疾病史，否认重大手术、外伤、输血、中毒史，否认明确药物、食物过敏史，预防接种史不详。"}
          ,{'ctx':"父死于“高血压、脑溢血”，母死于“气管炎”，有兄弟5人，均健在；否认2系3代家族性传染病、肿瘤、精神疾病、类似疾病及遗传疾病史。"}
          ,{'ctx': "月经史：13,6-7,30,50绝经后未见异常阴道出血史"}
          ]

for bo in zip(urls,params):
    a,b= bo
    print(a),print(b)
# Out:
# http://localhost:20001/api
# {'ctx': '出生生长于杭州，未久居外地。否认疫水疫源地接触史，无烟酒等不良嗜好，无不洁性交史；无职业性粉尘、放射性物质、毒物接触史；家庭关系和睦。'}
# http://localhost:20001/api
# {'ctx': '父母已亡，死因不详。兄弟姐妹5人，兄弟姐妹均已故。家族中无类似疾病患者；无传染性、遗传性、家族性疾病。'}
# http://localhost:20001/api
# {'ctx': '既往体尚健，否认肝炎、肺结核等传染病史，有“高血压、冠心病、前列腺增生、胆囊结石”等病史（见现病史），否认糖尿病、慢性肾炎等重大疾病史，否认重大手术、外伤、输血、中毒史，否认明确药物、食物过敏史，预防接种史不详。'}
# http://localhost:20001/api
# {'ctx': '父死于“高血压、脑溢血”，母死于“气管炎”，有兄弟5人，均健在；否认2系3代家族性传染病、肿瘤、精神疾病、类似疾病及遗传疾病史。'}
# http://localhost:20001/api
# {'ctx': '月经史：13,6-7,30,50绝经后未见异常阴道出血史'}

# %%
import time

start_time = time.time()
time.sleep(5)
print(time.time() - start_time)
# Out:
# 5.011845588684082

# %%
import csv

f = open("./test.csv", encoding="UTF-8")
freader = csv.reader(f)
header = next(freader)  # 获取 CSV 文件的头部信息

a = [row[1] for row in freader]
print(a)
# Out:
# ['预防接种史', '个人史', '家族史', '婚育史', '家族史', '手术史', '预防接种史', '个人史', '家族史', '主诉', '传染病史', '家族史', '婚育史', '婚育史', '外伤史', '现病史', '传染病史', '现病史', '预防接种史', '外伤史', '家族史', '现病史', '传染病史', '输血史', '既往史', '既往史', '现病史', '家族史', '家族史', '既往史', '手术史', '既往史', '手术史', '家族史', '输血史', '外伤史', '既往史', '主诉', '既往史', '既往史', '预防接种史', '预防接种史', '主诉', '个人史', '输血史', '现病史', '现病史', '手术史', '外伤史', '主诉', '既往史', '家族史', '主诉', '手术史', '既往史', '现病史', '外伤史', '主诉', '个人史', '主诉', '月经史', '传染病史', '手术史', '现病史', '预防接种史', '传染病史', '现病史', '主诉', '传染病史', '外伤史', '现病史', '个人史', '预防接种史', '预防接种史', '传染病史', '输血史', '现病史', '既往史', '既往史', '个人史', '月经史', '预防接种史', '现病史', '婚育史', '预防接种史', '外伤史', '预防接种史', '外伤史', '手术史', '家族史', '主诉', '婚育史', '外伤史', '家族史', '个人史', '既往史', '个人史', '主诉', '婚育史', '婚育史', '预防接种史', '现病史', '婚育史', '预防接种史', '传染病史', '外伤史', '家族史', '外伤史', '输血史', '预防接种史', '主诉', '预防接种史', '输血史', '家族史', '家族史', '预防接种史', '传染病史', '预防接种史', '主诉', '既往史', '输血史', '家族史', '手术史', '现病史', '既往史', '预防接种史', '既往史', '手术史', '传染病史', '输血史', '输血史', '预防接种史', '家族史', '外伤史', '传染病史', '主诉', '婚育史', '外
# ...

# %%
f = open("./test.log", encoding="UTF-8")
sum = 0
for i in f:
    sum = sum + float(i)

print(sum/100)
# Out:
# 4.660596976280212

# %%
f = open("./test_bert64.log", encoding="UTF-8")
sum = 0
for i in f:
    sum = sum + float(i)

print(sum/100)
# Out:
# 0.4097731590270996
